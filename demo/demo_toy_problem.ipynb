# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import datetime
import time
import os
plt.rcParams['image.cmap'] = 'gist_earth'

# %%
from tf_unet import image_gen
from tf_unet import unet
from tf_unet import util

# %%
nx = 572
ny = 572

# %%
generator = image_gen.GrayScaleDataProvider(nx, ny, cnt=20)

# %%
x_test, y_test = generator(1)

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")

# %%
net = unet.Unet(channels=generator.channels, n_class=generator.n_class, layers=3, features_root=16)
# Out:
# 2018-01-05 18:19:05,481 Layers 3, features 16, filter size 3x3, pool size: 2x2

# %%
trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
timestamp = str(int(time.time()))
out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
#path = trainer.train(generator,out_dir, training_iters=10, epochs=2, display_step=2)
print(out_dir)
path = trainer.train(generator, "./unet_trained", training_iters=10, epochs=2, display_step=2)
# Out:
# C:\Users\user\Dropbox\DeepLearningLecture\deep_galaxies\runs\1515172924
# 2018-01-05 18:22:06,517 Removing 'C:\Users\user\Dropbox\DeepLearningLecture\deep_galaxies\prediction'
# 2018-01-05 18:22:06,523 Removing 'C:\Users\user\Dropbox\DeepLearningLecture\deep_galaxies\unet_trained'
# 2018-01-05 18:22:06,540 Allocating 'C:\Users\user\Dropbox\DeepLearningLecture\deep_galaxies\prediction'
# 2018-01-05 18:22:21,449 Verification error= 16.6%, loss= 0.6688
# 2018-01-05 18:22:26,054 Start optimization
# 2018-01-05 18:22:35,126 Iter 0, Minibatch Loss= 0.6254, Training Accuracy= 0.8389, Minibatch error= 16.1%
# 2018-01-05 18:22:50,426 Iter 2, Minibatch Loss= 0.5766, Training Accuracy= 0.7929, Minibatch error= 20.7%
# 2018-01-05 18:23:05,622 Iter 4, Minibatch Loss= 0.4641, Training Accuracy= 0.8652, Minibatch error= 13.5%
# 2018-01-05 18:23:20,847 Iter 6, Minibatch Loss= 0.5195, Training Accuracy= 0.7993, Minibatch error= 20.1%
# ...

# %%
x_test, y_test = generator(1)

prediction = net.predict("./unet_trained/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./unet_trained/model.cpkt
# 2017-12-30 20:56:14,358 Restoring parameters from ./unet_trained/model.cpkt
# 2017-12-30 20:56:14,648 Model restored from file: ./unet_trained/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()
fig.savefig("./docs/toy_problem.png")
