# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
plt.rcParams['image.cmap'] = 'gist_earth'

# %%
from tf_unet import image_gen
from tf_unet import unet
from tf_unet import util

# %%
nx = 572
ny = 572

# %%
generator = image_gen.GrayScaleDataProvider(nx, ny, cnt=20)

# %%
x_test, y_test = generator(1)

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")

# %%
net = unet.Unet(channels=generator.channels, n_class=generator.n_class, layers=3, features_root=16)
# Out:
# 2017-11-27 15:15:31,177 Layers 3, features 16, filter size 3x3, pool size: 2x2

# %%
trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
path = trainer.train(generator, "./unet_trained", training_iters=20, epochs=10, display_step=2)
# Out:
# 2017-11-27 15:15:47,776 Removing '/home/magdalena/CAS_ETH/workspace/deep_learning/project/tf_unet/prediction'
# 2017-11-27 15:15:47,777 Removing '/home/magdalena/CAS_ETH/workspace/deep_learning/project/tf_unet/unet_trained'
# 2017-11-27 15:15:47,778 Allocating '/home/magdalena/CAS_ETH/workspace/deep_learning/project/tf_unet/prediction'
# 2017-11-27 15:15:47,779 Allocating '/home/magdalena/CAS_ETH/workspace/deep_learning/project/tf_unet/unet_trained'
# 2017-11-27 15:15:56,998 Verification error= 83.8%, loss= 0.7124
# 2017-11-27 15:16:00,266 Start optimization
# 2017-11-27 15:16:06,585 Iter 0, Minibatch Loss= 0.6184, Training Accuracy= 0.8218, Minibatch error= 17.8%
# 2017-11-27 15:16:17,440 Iter 2, Minibatch Loss= 0.5348, Training Accuracy= 0.8309, Minibatch error= 16.9%
# 2017-11-27 15:16:28,230 Iter 4, Minibatch Loss= 0.5098, Training Accuracy= 0.8143, Minibatch error= 18.6%
# 2017-11-27 15:16:38,981 Iter 6, Minibatch Loss= 0.5170, Training Accuracy= 0.7963, Minibatch error= 20.4%
# 2017-11-27 15:16:49,779 Iter 8, Minibatch Loss= 0.4887, Training Accuracy= 0.8167, Minibatch error= 18.3%
# 2017-11-27 15:17:00,539 Iter 10, Minibatch Loss= 0.4775, Training Accuracy= 0.8182, Minibatch error= 18.2%
# 2017-11-27 15:17:11,355 Iter 12, Minibatch Loss= 0.4888, Training Accuracy= 0.8064, Minibatch error= 19.4%
# 2017-11-27 15:17:22,123 Iter 14, Minibatch Loss= 0.5194, Training Accuracy= 0.7759, Minibatch error= 22.4%
# 2017-11-27 15:17:33,583 Iter 16, Minibatch Loss= 0.4111, Training Accuracy= 0.8496, Minibatch error= 15.0%
# 2017-11-27 15:17:48,250 Iter 18, Minibatch Loss= 0.4555, Training Accuracy= 0.8121, Minibatch error= 18.8%
# 2017-11-27 15:17:53,929 Epoch 0, Average loss: 0.5113, learning rate: 0.2000
# 2017-11-27 15:18:02,041 Verification error= 16.2%, loss= 0.4167
# 2017-11-27 15:18:10,676 Iter 20, Minibatch Loss= 0.4562, Training Accuracy= 0.8106, Minibatch error= 18.9%
# 2017-11-27 15:18:22,911 Iter 22, Minibatch Loss= 0.3563, Training Accuracy= 0.8660, Minibatch error= 13.4%
# 2017-11-27 15:18:36,601 Iter 24, Minibatch Loss= 0.4013, Training Accuracy= 0.8399, Minibatch error= 16.0%
# 2017-11-27 15:18:47,802 Iter 26, Minibatch Loss= 0.4177, Training Accuracy= 0.8140, Minibatch error= 18.6%
# 2017-11-27 15:18:58,572 Iter 28, Minibatch Loss= 0.3917, Training Accuracy= 0.8223, Minibatch error= 17.8%
# 2017-11-27 15:19:09,902 Iter 30, Minibatch Loss= 0.3071, Training Accuracy= 0.8597, Minibatch error= 14.0%
# 2017-11-27 15:19:21,819 Iter 32, Minibatch Loss= 0.3105, Training Accuracy= 0.8483, Minibatch error= 15.2%
# 2017-11-27 15:19:32,644 Iter 34, Minibatch Loss= 0.2841, Training Accuracy= 0.7955, Minibatch error= 20.5%
# 2017-11-27 15:19:44,551 Iter 36, Minibatch Loss= 0.3689, Training Accuracy= 0.8514, Minibatch error= 14.9%
# 2017-11-27 15:19:55,479 Iter 38, Minibatch Loss= 0.2507, Training Accuracy= 0.8192, Minibatch error= 18.1%
# 2017-11-27 15:20:00,245 Epoch 1, Average loss: 0.4006, learning rate: 0.1900
# 2017-11-27 15:20:08,377 Verification error= 16.2%, loss= 0.2384
# 2017-11-27 15:20:17,236 Iter 40, Minibatch Loss= 0.2803, Training Accuracy= 0.7502, Minibatch error= 25.0%
# 2017-11-27 15:20:28,017 Iter 42, Minibatch Loss= 0.1791, Training Accuracy= 0.8630, Minibatch error= 13.7%
# 2017-11-27 15:20:39,086 Iter 44, Minibatch Loss= 0.2626, Training Accuracy= 0.8042, Minibatch error= 19.6%
# 2017-11-27 15:20:51,155 Iter 46, Minibatch Loss= 0.2763, Training Accuracy= 0.7842, Minibatch error= 21.6%
# 2017-11-27 15:21:02,297 Iter 48, Minibatch Loss= 0.3272, Training Accuracy= 0.8265, Minibatch error= 17.4%
# 2017-11-27 15:21:13,548 Iter 50, Minibatch Loss= 0.1933, Training Accuracy= 0.8419, Minibatch error= 15.8%
# 2017-11-27 15:21:24,718 Iter 52, Minibatch Loss= 0.2678, Training Accuracy= 0.8363, Minibatch error= 16.4%
# 2017-11-27 15:21:36,345 Iter 54, Minibatch Loss= 0.1865, Training Accuracy= 0.8104, Minibatch error= 19.0%
# 2017-11-27 15:21:47,594 Iter 56, Minibatch Loss= 0.1871, Training Accuracy= 0.8163, Minibatch error= 18.4%
# 2017-11-27 15:21:58,377 Iter 58, Minibatch Loss= 1.0113, Training Accuracy= 0.8342, Minibatch error= 16.6%
# 2017-11-27 15:22:03,112 Epoch 2, Average loss: 0.3261, learning rate: 0.1805
# 2017-11-27 15:22:11,203 Verification error= 16.2%, loss= 0.2734
# 2017-11-27 15:22:20,299 Iter 60, Minibatch Loss= 0.2796, Training Accuracy= 0.7933, Minibatch error= 20.7%
# 2017-11-27 15:22:31,212 Iter 62, Minibatch Loss= 0.1921, Training Accuracy= 0.8272, Minibatch error= 17.3%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a63cbdba451f> in <module>()
# ----> 1 path = trainer.train(generator, "./unet_trained", training_iters=20, epochs=10, display_step=2)
#
# /home/magdalena/CAS_ETH/workspace/deep_learning/project/tf_unet/tf_unet/unet.py in train(self, data_provider, output_path, training_iters, epochs, dropout, display_step, restore, write_graph, prediction_path)
#     422                                                       feed_dict={self.net.x: batch_x,
#     423                                                                  self.net.y: util.crop_to_shape(batch_y, pred_shape),
# --> 424                                                                  self.net.keep_prob: dropout})
#     425
#     426                     if self.net.summaries and self.norm_grads:
#
# /home/magdalena/anaconda3/envs/ml/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/magdalena/anaconda3/envs/ml/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/magdalena/anaconda3/envs/ml/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/magdalena/anaconda3/envs/ml/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/magdalena/anaconda3/envs/ml/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
x_test, y_test = generator(1)

prediction = net.predict("./unet_trained/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./unet_trained/model.cpkt
# 2017-11-27 15:22:47,198 Restoring parameters from ./unet_trained/model.cpkt
# 2017-11-27 15:22:47,387 Model restored from file: ./unet_trained/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()
fig.savefig("./docs/toy_problem.png")
